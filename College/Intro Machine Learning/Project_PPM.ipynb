# %% [markdown]
# ##KELOMPOK 9
# 1. Ahmad Saifuddin - 195150200111038
# 2. Aldi Fianda Putra - 195150201111034
# 3. Noverio Athariq Syafaz - 195150207111036

# %%
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/00579/MI.data
# dataset dibawah alternatif, sudah ada nama kolomnya
# !wget https://s3-eu-west-1.amazonaws.com/pstorage-leicester-213265548798/23581310/MyocardialinfarctioncomplicationsDatabase.csv
# Out:
# --2021-06-15 09:52:20--  https://s3-eu-west-1.amazonaws.com/pstorage-leicester-213265548798/23581310/MyocardialinfarctioncomplicationsDatabase.csv
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.89.187
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.89.187|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 437563 (427K) [text/csv]
# Saving to: ‘MyocardialinfarctioncomplicationsDatabase.csv’
#
# Myocardialinfarctio 100%[===================>] 427.31K  --.-KB/s    in 0.09s
#
# 2021-06-15 09:52:20 (4.48 MB/s) - ‘MyocardialinfarctioncomplicationsDatabase.csv’ saved [437563/437563]

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('MyocardialinfarctioncomplicationsDatabase.csv')
data
# Out:
#         ID   AGE  SEX  INF_ANAM  ...  ZSN  REC_IM  P_IM_STEN  LET_IS
# 0        1  77.0    1       2.0  ...    0       0          0       0
# 1        2  55.0    1       1.0  ...    0       0          0       0
# 2        3  52.0    1       0.0  ...    0       0          0       0
# 3        4  68.0    0       0.0  ...    1       0          0       0
# 4        5  60.0    1       0.0  ...    0       0          0       0
# ...    ...   ...  ...       ...  ...  ...     ...        ...     ...
# 1695  1696  77.0    0       0.0  ...    0       0          0       3
# 1696  1697  70.0    0       0.0  ...    0       0          0       1
# 1697  1698  55.0    1       3.0  ...    0       1          0       6
# 1698  1699  79.0    0       2.0  ...    0       0          0       1
# 1699  1700  63.0    1       2.0  ...    0       0          0       1
#
# [1700 rows x 124 columns]

# %%
# Import Library 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import csv 
import math

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %% [markdown]
# ### Missing Value dan Imputasi Data (Pre-procesing)

# %%
def cetak_rentang(df_input):
  list_fitur=df_input.columns[:-1] #Mengambil nama kolom, 
  #Kecuali yang terakhir (kelas)
  for fitur in list_fitur:
    max=df_input[fitur].max()
    min=df_input[fitur].min()
    print("Rentang fitur", fitur, "Adalah", max-min)

# %%
cetak_rentang(data)
# Out:
# Rentang fitur ID Adalah 1699
# Rentang fitur AGE Adalah 66.0
# Rentang fitur SEX Adalah 1
# Rentang fitur INF_ANAM Adalah 3.0
# Rentang fitur STENOK_AN Adalah 6.0
# Rentang fitur FK_STENOK Adalah 4.0
# Rentang fitur IBS_POST Adalah 2.0
# Rentang fitur IBS_NASL Adalah 1.0
# Rentang fitur GB Adalah 3.0
# Rentang fitur SIM_GIPERT Adalah 1.0
# Rentang fitur DLIT_AG Adalah 7.0
# Rentang fitur ZSN_A Adalah 4.0
# Rentang fitur nr_11 Adalah 1.0
# Rentang fitur nr_01 Adalah 1.0
# Rentang fitur nr_02 Adalah 1.0
# Rentang fitur nr_03 Adalah 1.0
# Rentang fitur nr_04 Adalah 1.0
# Rentang fitur nr_07 Adalah 1.0
# Rentang fitur nr_08 Adalah 1.0
# Rentang fitur np_01 Adalah 1.0
# Rentang fitur np_04 Adalah 1.0
# Rentang fitur np_05 Adalah 1.0
# Rentang fitur np_07 Adalah 1.0
# Rentang fitur np_08 Adalah 1.0
# Rentang fitur np_09 Adalah 1.0
# Rentang fitur np_10 Adalah 1.0
# Rentang fitur endocr_01 Adalah 1.0
# Rentang fitur endocr_02 Adalah 1.0
# Rentang fitur endocr_03 Adalah 1.0
# ...

# %%
data.isnull().values.any()
# Out:
# True

# %%
def imputasi(df_input):
  list_columns = df_input.columns
  class_column = list_columns[-1]  
  for column in list_columns[:-1] :
    df_input[column] = df_input[column].fillna(round(df_input.groupby(class_column)[column].transform('mean'),0))
    df_input[column] = df_input[column].fillna(df_input[column].mean())
  return df_input

# %%
data = imputasi(data)

# %%
data
# Out:
#         ID   AGE  SEX  INF_ANAM  ...  ZSN  REC_IM  P_IM_STEN  LET_IS
# 0        1  77.0    1       2.0  ...    0       0          0       0
# 1        2  55.0    1       1.0  ...    0       0          0       0
# 2        3  52.0    1       0.0  ...    0       0          0       0
# 3        4  68.0    0       0.0  ...    1       0          0       0
# 4        5  60.0    1       0.0  ...    0       0          0       0
# ...    ...   ...  ...       ...  ...  ...     ...        ...     ...
# 1695  1696  77.0    0       0.0  ...    0       0          0       3
# 1696  1697  70.0    0       0.0  ...    0       0          0       1
# 1697  1698  55.0    1       3.0  ...    0       1          0       6
# 1698  1699  79.0    0       2.0  ...    0       0          0       1
# 1699  1700  63.0    1       2.0  ...    0       0          0       1
#
# [1700 rows x 124 columns]

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# Pada data imputasi diatas terlihat sudah tidak ada data yang hilang sehingga kita dapat melakukan normalisasi. Data yang dinormalisasi hanya data kontinu atau data non kategorikal saja.

# %%
kolomfitur = ['S_AD_KBRIG','D_AD_KBRIG','S_AD_ORIT','D_AD_ORIT','K_BLOOD','NA_BLOOD',
              'ALT_BLOOD','AST_BLOOD','KFK_BLOOD','L_BLOOD','ROE']
from sklearn.preprocessing import MinMaxScaler
normalisasi = MinMaxScaler()
data[kolomfitur] = normalisasi.fit_transform(data[kolomfitur])

# %%
data
# Out:
#         ID   AGE  SEX  INF_ANAM  ...  ZSN  REC_IM  P_IM_STEN  LET_IS
# 0        1  77.0    1       2.0  ...    0       0          0       0
# 1        2  55.0    1       1.0  ...    0       0          0       0
# 2        3  52.0    1       0.0  ...    0       0          0       0
# 3        4  68.0    0       0.0  ...    1       0          0       0
# 4        5  60.0    1       0.0  ...    0       0          0       0
# ...    ...   ...  ...       ...  ...  ...     ...        ...     ...
# 1695  1696  77.0    0       0.0  ...    0       0          0       3
# 1696  1697  70.0    0       0.0  ...    0       0          0       1
# 1697  1698  55.0    1       3.0  ...    0       1          0       6
# 1698  1699  79.0    0       2.0  ...    0       0          0       1
# 1699  1700  63.0    1       2.0  ...    0       0          0       1
#
# [1700 rows x 124 columns]

# %%
cetak_rentang(data)
# Out:
# Rentang fitur ID Adalah 1699
# Rentang fitur AGE Adalah 66.0
# Rentang fitur SEX Adalah 1
# Rentang fitur INF_ANAM Adalah 3.0
# Rentang fitur STENOK_AN Adalah 6.0
# Rentang fitur FK_STENOK Adalah 4.0
# Rentang fitur IBS_POST Adalah 2.0
# Rentang fitur IBS_NASL Adalah 1.0
# Rentang fitur GB Adalah 3.0
# Rentang fitur SIM_GIPERT Adalah 1.0
# Rentang fitur DLIT_AG Adalah 7.0
# Rentang fitur ZSN_A Adalah 4.0
# Rentang fitur nr_11 Adalah 1.0
# Rentang fitur nr_01 Adalah 1.0
# Rentang fitur nr_02 Adalah 1.0
# Rentang fitur nr_03 Adalah 1.0
# Rentang fitur nr_04 Adalah 1.0
# Rentang fitur nr_07 Adalah 1.0
# Rentang fitur nr_08 Adalah 1.0
# Rentang fitur np_01 Adalah 1.0
# Rentang fitur np_04 Adalah 1.0
# Rentang fitur np_05 Adalah 1.0
# Rentang fitur np_07 Adalah 1.0
# Rentang fitur np_08 Adalah 1.0
# Rentang fitur np_09 Adalah 1.0
# Rentang fitur np_10 Adalah 1.0
# Rentang fitur endocr_01 Adalah 1.0
# Rentang fitur endocr_02 Adalah 1.0
# Rentang fitur endocr_03 Adalah 1.0
# ...

# %% [markdown]
# Rentang fitur datanya sekarang sudah 1.0 kecuali data yang bersifat kategorikal

# %% [markdown]
# ## Evaluasi Algoritma Naive Bayes, Decision Tree dan SVM

# %% [markdown]
# ### Pembuatan Model Klasifikasi

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report

models = []
models.append(('NB', GaussianNB()))
models.append(('DT', DecisionTreeClassifier()))
models.append(('SVM', SVC(gamma='auto')))

results = []
names = []

# %% [markdown]
# ### Pembuatan Set Data Validasi dan K-Fold Cross Validation

# %% [markdown]
# Pembagian data tarining/latih dan data validation/uji dengan skala 80:20.

# %%
array = data.values
X = array[:,0:123]
y = array[:,123]

X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1, shuffle=True)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings("ignore")

for name, model in models:
	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
	results.append(cv_results)
	names.append(name)
	print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# NB: 0.510294 (0.040031)
# DT: 0.968382 (0.012326)
# SVM: 0.892647 (0.013235)

# %%
y
# Out:
# array([0., 0., 0., ..., 6., 1., 1.])

# %% [markdown]
# ### Prediksi Naive Bayes

# %%
model = GaussianNB()
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
print(classification_report(Y_validation, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.50      0.67       296
#          1.0       0.44      0.21      0.29        19
#          2.0       0.05      0.67      0.10         3
#          3.0       1.00      1.00      1.00         8
#          4.0       0.00      0.00      0.00         7
#          5.0       0.02      0.33      0.03         3
#          6.0       0.00      0.00      0.00         2
#          7.0       0.00      0.00      0.00         2
#
#     accuracy                           0.48       340
#    macro avg       0.31      0.34      0.26       340
# weighted avg       0.91      0.48      0.62       340

# %% [markdown]
# ### Prediksi SVM

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, Y_train)

# %%
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
X, y = make_classification(n_samples=340, n_features=20, n_informative=15, n_redundant=5, random_state=1)
print(classification_report(Y_validation, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98       296
#          1.0       0.52      0.74      0.61        19
#          2.0       0.00      0.00      0.00         3
#          3.0       0.50      0.38      0.43         8
#          4.0       1.00      0.14      0.25         7
#          5.0       0.00      0.00      0.00         3
#          6.0       0.00      0.00      0.00         2
#          7.0       1.00      0.50      0.67         2
#
#     accuracy                           0.92       340
#    macro avg       0.50      0.34      0.37       340
# weighted avg       0.91      0.92      0.91       340

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
y_pred = model.predict(X_validation) # prediksi

# %% [markdown]
# ### Prediksi Decision Tree

# %%
model = DecisionTreeClassifier()
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
print(classification_report(Y_validation, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       296
#          1.0       0.86      1.00      0.93        19
#          2.0       1.00      0.33      0.50         3
#          3.0       1.00      1.00      1.00         8
#          4.0       1.00      1.00      1.00         7
#          5.0       0.67      0.67      0.67         3
#          6.0       1.00      1.00      1.00         2
#          7.0       0.50      0.50      0.50         2
#
#     accuracy                           0.99       340
#    macro avg       0.88      0.81      0.82       340
# weighted avg       0.99      0.99      0.98       340

# %%
from sklearn.metrics import multilabel_confusion_matrix
multilabel_confusion_matrix(Y_validation, predictions,labels=[2])
# Out:
# array([[[337,   0],
#         [  2,   1]]])

# %%
tn, fp, fn, tp = multilabel_confusion_matrix(Y_validation, y_pred,labels=[2]).ravel()

# %%
fp
# Out:
# 0
